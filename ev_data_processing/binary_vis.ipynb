# %% [markdown]
# ## 1. Read data
# ### 1.1 Checking available streams

# %%
import dv_processing as dv

# Store the file path
path_to_file = "../data/robotics.aedat4"

# Open a file
reader = dv.io.MonoCameraRecording(path_to_file)

# Print file path and camera name
print(f"Checking available streams in [{path_to_file}] for camera name [{reader.getCameraName()}]:")

# Check if event stream is available
if reader.isEventStreamAvailable():
    # # Check the resolution of event stream
    resolution = reader.getEventResolution()

    # # Print that the stream is present and its resolution
    # print(f"  * Event stream with resolution [{resolution.width}x{resolution.height}]")
    # Access the width and height from the tuple
    
    width, height = resolution
    # Print that the stream is present and its resolution
    print(f"  * Event stream with resolution [{width}x{height}]")

# Check if frame stream is available
if reader.isFrameStreamAvailable():
    # Check the resolution of frame stream
    resolution = reader.getFrameResolution()

    # Print that the stream is available and its resolution
    print(f"  * Frame stream with resolution [{resolution.width}x{resolution.height}]")

# Check if IMU stream is available
if reader.isImuStreamAvailable():
    # Print that the IMU stream is available
    print("  * IMU stream")

# Check if trigger stream is available
if reader.isTriggerStreamAvailable():
    # Print that the trigger stream is available
    print("  * Trigger stream")
# Out:
# Checking available streams in [../data/robotics.aedat4] for camera name [DVXplorer_DXM00071]:
#   * Event stream with resolution [640x480]
#   * IMU stream
#   * Trigger stream

# %% [markdown]
# ### 1.2 Read different type of data

# %% [markdown]
# **Read events from a file**

# %%
import dv_processing as dv

# Open any camera
reader = dv.io.MonoCameraRecording("../data/robotics.aedat4")

# Run the loop while camera is still connected
while reader.isRunning():
    # Read batch of events
    events = reader.getNextEventBatch()
    if events is not None:
        # Print received packet time range
        print(f"{events}")
# Out:
# EventStore containing 21759 events within 9808µs duration; time range within [1724848695373335; 1724848695383143]
# EventStore containing 16733 events within 9808µs duration; time range within [1724848695383343; 1724848695393151]
# EventStore containing 31444 events within 9808µs duration; time range within [1724848695393351; 1724848695403159]
# EventStore containing 27270 events within 9807µs duration; time range within [1724848695403360; 1724848695413167]
# EventStore containing 30727 events within 9808µs duration; time range within [1724848695413367; 1724848695423175]
# EventStore containing 34700 events within 9808µs duration; time range within [1724848695423375; 1724848695433183]
# EventStore containing 55218 events within 9810µs duration; time range within [1724848695433383; 1724848695443193]
# EventStore containing 30233 events within 9808µs duration; time range within [1724848695443393; 1724848695453201]
# EventStore containing 30141 events within 9808µs duration; time range within [1724848695453401; 1724848695463209]
# EventStore containing 25507 events within 9808µs duration; time range within [1724848695463409; 1724848695473217]
# EventStore containing 34231 events within 9808µs duration; time range within [1724848695473417; 1724848695483225]
# EventStore containing 26797 events within 9809µs duration; time range within [1724848695483425; 1724848695493234]
# EventStore containing 43204 events within 9807µs duration; time range within [1724848695493434; 1724848695503241]
# EventStore containing 29374 events within 9809µs duration; time range within [1724848695503441; 1724848695513250]
# EventStore containing 37480 events within 9806µs duration; time range within [1724848695513451; 1724848695523257]
# EventStore containing 24161 events within 9810µs duration; time range within [1724848695523457; 1724848695533267]
# EventStore containing 33106 events within 9808µs duration; time range within [1724848695533465; 1724848695543273]
# EventStore containing 31211 events within 9809µs duration; time range within [1724848695543473; 1724848695553282]
# EventStore containing 27921 events within 9807µs duration; time range within [1724848695553482; 1724848695563289]
# EventStore containing 29480 events within 9810µs duration; time range within [1724848695563489; 1724848695573299]
# EventStore containing 25197 events within 9806µs duration; time range within [1724848695573499; 1724848695583305]
# EventStore containing 18583 events within 9609µs duration; time range within [1724848695583505; 1724848695593114]
# EventStore containing 35463 events within 9806µs duration; time range within [1724848695593315; 1724848695603121]
# EventStore containing 23499 events within 9808µs duration; time range within [1724848695603321; 1724848695613129]
# EventStore containing 36281 events within 9809µs duration; time range within [1724848695613331; 1724848695623140]
# EventStore containing 20012 events within 9807µs duration; time range within [1724848695623338; 1724848695633145]
# EventStore containing 31042 events within 9798µs duration; time range within [1724848695633355; 1724848695643153]
# EventStore containing 19800 events within 9808µs duration; time range within [1724848695643353; 1724848695653161]
# EventStore containing 25755 events within 9808µs duration; time range within [1724848695653361; 1724848695663169]
# EventStore containing 23200 events within 9806µs duration; time range within [1724848695663371; 1724848695673177]
# EventStore containing 24248 events within 9808µs duration; time range within [1724848695673377; 1724848695683185]
# EventStore containing 20952 events within 9807µs duration; time range within [1724848695683386; 1724848695693193]
# EventStore containing 31786 events within 9808µs duration; time range within [1724848695693393; 1724848695703201]
# EventStore containing 22879 events within 9808µs duration; time range within [1724848695703401; 1724848695713209]
# EventStore containing 17152 events within 9809µs duration; time range within [1724848695713410; 1724848695723219]
# EventStore containing 23852 events within 9808µs duration; time range within [1724848695723418; 1724848695733226]
# EventStore containing 24049 events within 9808µs duration; time range within [1724848695733425; 1724848695743233]
# EventStore containing 21306 events within 9808µs duration; time range within [1724848695743433; 1724848695753241]
# EventStore containing 20710 events within 9808µs duration; time range within [1724848695753441; 1724848695763249]
# EventStore containing 28543 events within 9807µs duration; time range within [1724848695763451; 1724848695773258]
# EventStore containing 18823 events within 9808µs duration; time range within [1724848695773459; 1724848695783267]
# EventStore containing 19446 events within 9807µs duration; time range within [1724848695783466; 1724848695793273]
# EventStore containing 26040 events within 9808µs duration; time range within [1724848695793475; 1724848695803283]
# EventStore containing 20597 events within 9807µs duration; time range within [1724848695803483; 1724848695813290]
# EventStore containing 15244 events within 9808µs duration; time range within [1724848695813489; 1724848695823297]
# EventStore containing 21300 events within 9809µs duration; time range within [1724848695823497; 1724848695833306]
# EventStore containing 14738 events within 9606µs duration; time range within [1724848695833507; 1724848695843113]
# EventStore containing 24254 events within 9807µs duration; time range within [1724848695843314; 1724848695853121]
# EventStore containing 27130 events within 9807µs duration; time range within [1724848695853323; 1724848695863130]
# EventStore containing 22832 events within 9808µs duration; time range within [1724848695863329; 1724848695873137]
# EventStore containing 41468 events within 9808µs duration; time range within [1724848695873337; 1724848695883145]
# EventStore containing 44401 events within 9808µs duration; time range within [1724848695883345; 1724848695893153]
# EventStore containing 39876 events within 9807µs duration; time range within [1724848695893354; 1724848695903161]
# EventStore containing 29977 events within 9808µs duration; time range within [1724848695903361; 1724848695913169]
# EventStore containing 41201 events within 9808µs duration; time range within [1724848695913369; 1724848695923177]
# EventStore containing 27108 events within 9808µs duration; time range within [1724848695923377; 1724848695933185]
# EventStore containing 25052 events within 9808µs duration; time range within [1724848695933385; 1724848695943193]
# EventStore containing 29058 events within 9808µs duration; time range within [1724848695943393; 1724848695953201]
# EventStore containing 49254 events within 9808µs duration; time range within [1724848695953401; 1724848695963209]
# EventStore containing 51396 events within 9808µs duration; time range within [1724848695963409; 1724848695973217]
# EventStore containing 36443 events within 9808µs duration; time range within [1724848695973417; 1724848695983225]
# EventStore containing 50145 events within 9808µs duration; time range within [1724848695983425; 1724848695993233]
# EventStore containing 53933 events within 9808µs duration; time range within [1724848695993433; 1724848696003241]
# EventStore containing 44487 events within 9808µs duration; time range within [1724848696003441; 1724848696013249]
# EventStore containing 39494 events within 9808µs duration; time range within [1724848696013449; 1724848696023257]
# EventStore containing 40138 events within 9807µs duration; time range within [1724848696023458; 1724848696033265]
# EventStore containing 41645 events within 9808µs duration; time range within [1724848696033465; 1724848696043273]
# EventStore containing 32482 events within 9809µs duration; time range within [1724848696043473; 1724848696053282]
# EventStore containing 36498 events within 9808µs duration; time range within [1724848696053481; 1724848696063289]
# EventStore containing 27038 events within 9808µs duration; time range within [1724848696063489; 1724848696073297]
# EventStore containing 23525 events within 9808µs duration; time range within [1724848696073497; 1724848696083305]
# EventStore containing 19415 events within 9608µs duration; time range within [1724848696083505; 1724848696093113]
# EventStore containing 19351 events within 9808µs duration; time range within [1724848696093314; 1724848696103122]
# EventStore containing 35461 events within 9807µs duration; time range within [1724848696103322; 1724848696113129]
# EventStore containing 41193 events within 9808µs duration; time range within [1724848696113329; 1724848696123137]
# EventStore containing 28479 events within 9807µs duration; time range within [1724848696123338; 1724848696133145]
# EventStore containing 25529 events within 9809µs duration; time range within [1724848696133346; 1724848696143155]
# EventStore containing 32373 events within 9809µs duration; time range within [1724848696143353; 1724848696153162]
# EventStore containing 21371 events within 9808µs duration; time range within [1724848696153362; 1724848696163170]
# EventStore containing 23088 events within 9806µs duration; time range within [1724848696163372; 1724848696173178]
# EventStore containing 19381 events within 9807µs duration; time range within [1724848696173379; 1724848696183186]
# EventStore containing 21142 events within 9809µs duration; time range within [1724848696183385; 1724848696193194]
# EventStore containing 18885 events within 9807µs duration; time range within [1724848696193394; 1724848696203201]
# EventStore containing 27069 events within 9808µs duration; time range within [1724848696203401; 1724848696213209]
# EventStore containing 23163 events within 9808µs duration; time range within [1724848696213409; 1724848696223217]
# EventStore containing 17956 events within 9808µs duration; time range within [1724848696223418; 1724848696233226]
# EventStore containing 18537 events within 9807µs duration; time range within [1724848696233426; 1724848696243233]
# EventStore containing 20396 events within 9808µs duration; time range within [1724848696243433; 1724848696253241]
# EventStore containing 20155 events within 9808µs duration; time range within [1724848696253441; 1724848696263249]
# EventStore containing 32261 events within 9807µs duration; time range within [1724848696263450; 1724848696273257]
# EventStore containing 33452 events within 9808µs duration; time range within [1724848696273457; 1724848696283265]
# EventStore containing 30485 events within 9809µs duration; time range within [1724848696283465; 1724848696293274]
# EventStore containing 23870 events within 9809µs duration; time range within [1724848696293473; 1724848696303282]
# EventStore containing 25445 events within 9807µs duration; time range within [1724848696303482; 1724848696313289]
# EventStore containing 33573 events within 9808µs duration; time range within [1724848696313489; 1724848696323297]
# EventStore containing 28507 events within 9808µs duration; time range within [1724848696323497; 1724848696333305]
# EventStore containing 31847 events within 9608µs duration; time range within [1724848696333505; 1724848696343113]
# EventStore containing 34938 events within 9808µs duration; time range within [1724848696343313; 1724848696353121]
# EventStore containing 23439 events within 9808µs duration; time range within [1724848696353321; 1724848696363129]
# EventStore containing 22685 events within 9808µs duration; time range within [1724848696363329; 1724848696373137]
# EventStore containing 17172 events within 9809µs duration; time range within [1724848696373337; 1724848696383146]
# EventStore containing 14693 events within 9808µs duration; time range within [1724848696383346; 1724848696393154]
# EventStore containing 15736 events within 9808µs duration; time range within [1724848696393354; 1724848696403162]
# EventStore containing 26736 events within 9808µs duration; time range within [1724848696403361; 1724848696413169]
# EventStore containing 16354 events within 9810µs duration; time range within [1724848696413369; 1724848696423179]
# EventStore containing 18231 events within 9808µs duration; time range within [1724848696423377; 1724848696433185]
# EventStore containing 19005 events within 9812µs duration; time range within [1724848696433385; 1724848696443197]
# EventStore containing 14677 events within 9808µs duration; time range within [1724848696443393; 1724848696453201]
# EventStore containing 19526 events within 9808µs duration; time range within [1724848696453401; 1724848696463209]
# EventStore containing 27055 events within 9804µs duration; time range within [1724848696463413; 1724848696473217]
# EventStore containing 28858 events within 9808µs duration; time range within [1724848696473417; 1724848696483225]
# EventStore containing 38652 events within 9808µs duration; time range within [1724848696483426; 1724848696493234]
# EventStore containing 32391 events within 9808µs duration; time range within [1724848696493434; 1724848696503242]
# EventStore containing 27809 events within 9809µs duration; time range within [1724848696503442; 1724848696513251]
# EventStore containing 29707 events within 9807µs duration; time range within [1724848696513451; 1724848696523258]
# EventStore containing 21547 events within 9809µs duration; time range within [1724848696523458; 1724848696533267]
# EventStore containing 15981 events within 9809µs duration; time range within [1724848696533466; 1724848696543275]
# EventStore containing 15340 events within 9808µs duration; time range within [1724848696543474; 1724848696553282]
# EventStore containing 23354 events within 9808µs duration; time range within [1724848696553482; 1724848696563290]
# EventStore containing 32627 events within 9808µs duration; time range within [1724848696563490; 1724848696573298]
# EventStore containing 31491 events within 9808µs duration; time range within [1724848696573498; 1724848696583306]
# EventStore containing 25705 events within 9607µs duration; time range within [1724848696583506; 1724848696593113]
# EventStore containing 30090 events within 9807µs duration; time range within [1724848696593314; 1724848696603121]
# EventStore containing 28595 events within 9808µs duration; time range within [1724848696603322; 1724848696613130]
# EventStore containing 35862 events within 9807µs duration; time range within [1724848696613331; 1724848696623138]
# EventStore containing 29689 events within 9808µs duration; time range within [1724848696623338; 1724848696633146]
# EventStore containing 43403 events within 9809µs duration; time range within [1724848696633346; 1724848696643155]
# EventStore containing 33359 events within 9808µs duration; time range within [1724848696643355; 1724848696653163]
# EventStore containing 28809 events within 9808µs duration; time range within [1724848696653363; 1724848696663171]
# EventStore containing 31278 events within 9807µs duration; time range within [1724848696663372; 1724848696673179]
# EventStore containing 21257 events within 9807µs duration; time range within [1724848696673380; 1724848696683187]
# EventStore containing 19198 events within 9809µs duration; time range within [1724848696683387; 1724848696693196]
# EventStore containing 16084 events within 9807µs duration; time range within [1724848696693397; 1724848696703204]
# EventStore containing 16166 events within 9808µs duration; time range within [1724848696703403; 1724848696713211]
# EventStore containing 30366 events within 9808µs duration; time range within [1724848696713411; 1724848696723219]
# EventStore containing 34395 events within 9809µs duration; time range within [1724848696723419; 1724848696733228]
# EventStore containing 30810 events within 9808µs duration; time range within [1724848696733427; 1724848696743235]
# EventStore containing 26337 events within 9809µs duration; time range within [1724848696743435; 1724848696753244]
# EventStore containing 22200 events within 9808µs duration; time range within [1724848696753443; 1724848696763251]
# EventStore containing 18800 events within 9810µs duration; time range within [1724848696763451; 1724848696773261]
# EventStore containing 21729 events within 9809µs duration; time range within [1724848696773460; 1724848696783269]
# EventStore containing 19432 events within 9809µs duration; time range within [1724848696783467; 1724848696793276]
# EventStore containing 27444 events within 9808µs duration; time range within [1724848696793475; 1724848696803283]
# EventStore containing 29000 events within 9807µs duration; time range within [1724848696803484; 1724848696813291]
# EventStore containing 25325 events within 9808µs duration; time range within [1724848696813491; 1724848696823299]
# EventStore containing 33025 events within 9806µs duration; time range within [1724848696823501; 1724848696833307]
# EventStore containing 24702 events within 9608µs duration; time range within [1724848696833507; 1724848696843115]
# EventStore containing 32471 events within 9808µs duration; time range within [1724848696843315; 1724848696853123]
# EventStore containing 26226 events within 9808µs duration; time range within [1724848696853323; 1724848696863131]
# EventStore containing 28342 events within 9808µs duration; time range within [1724848696863331; 1724848696873139]
# EventStore containing 20882 events within 9808µs duration; time range within [1724848696873339; 1724848696883147]
# EventStore containing 33515 events within 9808µs duration; time range within [1724848696883347; 1724848696893155]
# EventStore containing 24452 events within 9809µs duration; time range within [1724848696893355; 1724848696903164]
# EventStore containing 25906 events within 9807µs duration; time range within [1724848696903364; 1724848696913171]
# EventStore containing 20667 events within 9808µs duration; time range within [1724848696913371; 1724848696923179]
# EventStore containing 27777 events within 9809µs duration; time range within [1724848696923379; 1724848696933188]
# EventStore containing 22341 events within 9808µs duration; time range within [1724848696933387; 1724848696943195]
# EventStore containing 34360 events within 9808µs duration; time range within [1724848696943396; 1724848696953204]
# EventStore containing 33754 events within 9808µs duration; time range within [1724848696953403; 1724848696963211]
# EventStore containing 27561 events within 9808µs duration; time range within [1724848696963411; 1724848696973219]
# EventStore containing 32333 events within 9808µs duration; time range within [1724848696973419; 1724848696983227]
# EventStore containing 25598 events within 9808µs duration; time range within [1724848696983427; 1724848696993235]
# EventStore containing 41215 events within 9807µs duration; time range within [1724848696993436; 1724848697003243]
# EventStore containing 36025 events within 9808µs duration; time range within [1724848697003443; 1724848697013251]
# EventStore containing 39824 events within 9808µs duration; time range within [1724848697013451; 1724848697023259]
# EventStore containing 32990 events within 9808µs duration; time range within [1724848697023459; 1724848697033267]
# EventStore containing 24019 events within 9808µs duration; time range within [1724848697033467; 1724848697043275]
# EventStore containing 25064 events within 9808µs duration; time range within [1724848697043475; 1724848697053283]
# EventStore containing 28044 events within 9808µs duration; time range within [1724848697053483; 1724848697063291]
# EventStore containing 26976 events within 9807µs duration; time range within [1724848697063492; 1724848697073299]
# EventStore containing 22852 events within 9808µs duration; time range within [1724848697073499; 1724848697083307]
# EventStore containing 21497 events within 9607µs duration; time range within [1724848697083508; 1724848697093115]
# EventStore containing 25807 events within 9807µs duration; time range within [1724848697093315; 1724848697103122]
# EventStore containing 24583 events within 9808µs duration; time range within [1724848697103323; 1724848697113131]
# EventStore containing 25906 events within 9807µs duration; time range within [1724848697113331; 1724848697123138]
# EventStore containing 21797 events within 9810µs duration; time range within [1724848697123339; 1724848697133149]
# EventStore containing 24781 events within 9808µs duration; time range within [1724848697133347; 1724848697143155]
# EventStore containing 37056 events within 9807µs duration; time range within [1724848697143355; 1724848697153162]
# EventStore containing 28876 events within 9808µs duration; time range within [1724848697153363; 1724848697163171]
# EventStore containing 31198 events within 9808µs duration; time range within [1724848697163371; 1724848697173179]
# EventStore containing 27727 events within 9808µs duration; time range within [1724848697173379; 1724848697183187]
# EventStore containing 21561 events within 9807µs duration; time range within [1724848697183387; 1724848697193194]
# EventStore containing 20210 events within 9807µs duration; time range within [1724848697193395; 1724848697203202]
# EventStore containing 18766 events within 9806µs duration; time range within [1724848697203404; 1724848697213210]
# EventStore containing 23887 events within 9807µs duration; time range within [1724848697213412; 1724848697223219]
# EventStore containing 20851 events within 9808µs duration; time range within [1724848697223419; 1724848697233227]
# EventStore containing 18168 events within 9807µs duration; time range within [1724848697233428; 1724848697243235]
# EventStore containing 29883 events within 9808µs duration; time range within [1724848697243435; 1724848697253243]
# EventStore containing 39980 events within 9808µs duration; time range within [1724848697253443; 1724848697263251]
# EventStore containing 31675 events within 9808µs duration; time range within [1724848697263451; 1724848697273259]
# EventStore containing 31605 events within 9808µs duration; time range within [1724848697273459; 1724848697283267]
# EventStore containing 20842 events within 9808µs duration; time range within [1724848697283467; 1724848697293275]
# EventStore containing 22099 events within 9808µs duration; time range within [1724848697293475; 1724848697303283]
# EventStore containing 23839 events within 9808µs duration; time range within [1724848697303483; 1724848697313291]
# EventStore containing 26858 events within 9808µs duration; time range within [1724848697313491; 1724848697323299]
# EventStore containing 46537 events within 9808µs duration; time range within [1724848697323499; 1724848697333307]
# EventStore containing 33286 events within 9607µs duration; time range within [1724848697333507; 1724848697343114]
# EventStore containing 28874 events within 9807µs duration; time range within [1724848697343315; 1724848697353122]
# EventStore containing 32505 events within 9808µs duration; time range within [1724848697353323; 1724848697363131]
# EventStore containing 29802 events within 9808µs duration; time range within [1724848697363331; 1724848697373139]
# EventStore containing 34923 events within 9808µs duration; time range within [1724848697373339; 1724848697383147]
# EventStore containing 37000 events within 9807µs duration; time range within [1724848697383347; 1724848697393154]
# EventStore containing 24434 events within 9808µs duration; time range within [1724848697393355; 1724848697403163]
# EventStore containing 29705 events within 9807µs duration; time range within [1724848697403363; 1724848697413170]
# EventStore containing 26675 events within 9807µs duration; time range within [1724848697413371; 1724848697423178]
# EventStore containing 24642 events within 9809µs duration; time range within [1724848697423379; 1724848697433188]
# EventStore containing 36266 events within 9808µs duration; time range within [1724848697433387; 1724848697443195]
# EventStore containing 40183 events within 9808µs duration; time range within [1724848697443395; 1724848697453203]
# EventStore containing 45092 events within 9808µs duration; time range within [1724848697453403; 1724848697463211]
# EventStore containing 48709 events within 9808µs duration; time range within [1724848697463411; 1724848697473219]
# EventStore containing 43727 events within 9808µs duration; time range within [1724848697473419; 1724848697483227]
# EventStore containing 30325 events within 9808µs duration; time range within [1724848697483427; 1724848697493235]
# EventStore containing 31107 events within 9808µs duration; time range within [1724848697493435; 1724848697503243]
# EventStore containing 38325 events within 9808µs duration; time range within [1724848697503443; 1724848697513251]
# EventStore containing 29901 events within 9808µs duration; time range within [1724848697513451; 1724848697523259]
# EventStore containing 28598 events within 9808µs duration; time range within [1724848697523459; 1724848697533267]
# EventStore containing 20252 events within 9808µs duration; time range within [1724848697533467; 1724848697543275]
# EventStore containing 26388 events within 9807µs duration; time range within [1724848697543476; 1724848697553283]
# EventStore containing 46804 events within 9808µs duration; time range within [1724848697553483; 1724848697563291]
# EventStore containing 31874 events within 9808µs duration; time range within [1724848697563491; 1724848697573299]
# EventStore containing 26355 events within 9608µs duration; time range within [1724848697573499; 1724848697583107]
# EventStore containing 35988 events within 9807µs duration; time range within [1724848697583308; 1724848697593115]
# EventStore containing 33547 events within 9808µs duration; time range within [1724848697593315; 1724848697603123]
# EventStore containing 40080 events within 9808µs duration; time range within [1724848697603323; 1724848697613131]
# EventStore containing 40327 events within 9808µs duration; time range within [1724848697613331; 1724848697623139]
# EventStore containing 45079 events within 9808µs duration; time range within [1724848697623339; 1724848697633147]
# EventStore containing 26612 events within 9808µs duration; time range within [1724848697633347; 1724848697643155]
# EventStore containing 27129 events within 9808µs duration; time range within [1724848697643355; 1724848697653163]
# EventStore containing 19196 events within 9808µs duration; time range within [1724848697653363; 1724848697663171]
# EventStore containing 22823 events within 9805µs duration; time range within [1724848697663374; 1724848697673179]
# EventStore containing 19928 events within 9808µs duration; time range within [1724848697673379; 1724848697683187]
# EventStore containing 37786 events within 9808µs duration; time range within [1724848697683387; 1724848697693195]
# EventStore containing 41037 events within 9809µs duration; time range within [1724848697693395; 1724848697703204]
# EventStore containing 54547 events within 9808µs duration; time range within [1724848697703404; 1724848697713212]
# EventStore containing 35286 events within 9808µs duration; time range within [1724848697713412; 1724848697723220]
# EventStore containing 33533 events within 9808µs duration; time range within [1724848697723420; 1724848697733228]
# EventStore containing 34805 events within 9808µs duration; time range within [1724848697733428; 1724848697743236]
# EventStore containing 33424 events within 9808µs duration; time range within [1724848697743436; 1724848697753244]
# EventStore containing 38265 events within 9808µs duration; time range within [1724848697753444; 1724848697763252]
# EventStore containing 35745 events within 9808µs duration; time range within [1724848697763452; 1724848697773260]
# EventStore containing 27532 events within 9808µs duration; time range within [1724848697773460; 1724848697783268]
# EventStore containing 44006 events within 9808µs duration; time range within [1724848697783468; 1724848697793276]
# EventStore containing 29213 events within 9808µs duration; time range within [1724848697793476; 1724848697803284]
# EventStore containing 36044 events within 9808µs duration; time range within [1724848697803484; 1724848697813292]
# EventStore containing 41412 events within 9808µs duration; time range within [1724848697813492; 1724848697823300]
# EventStore containing 23442 events within 9607µs duration; time range within [1724848697823500; 1724848697833107]
# EventStore containing 24713 events within 9808µs duration; time range within [1724848697833308; 1724848697843116]
# EventStore containing 20307 events within 9812µs duration; time range within [1724848697843316; 1724848697853128]
# EventStore containing 23845 events within 9807µs duration; time range within [1724848697853324; 1724848697863131]
# EventStore containing 30457 events within 9806µs duration; time range within [1724848697863333; 1724848697873139]
# EventStore containing 17871 events within 9807µs duration; time range within [1724848697873340; 1724848697883147]
# EventStore containing 27035 events within 9807µs duration; time range within [1724848697883348; 1724848697893155]
# EventStore containing 17024 events within 9808µs duration; time range within [1724848697893356; 1724848697903164]
# EventStore containing 21226 events within 9808µs duration; time range within [1724848697903364; 1724848697913172]
# EventStore containing 19701 events within 9808µs duration; time range within [1724848697913372; 1724848697923180]
# EventStore containing 22484 events within 9808µs duration; time range within [1724848697923380; 1724848697933188]
# EventStore containing 24681 events within 9806µs duration; time range within [1724848697933389; 1724848697943195]
# EventStore containing 20255 events within 9808µs duration; time range within [1724848697943396; 1724848697953204]
# EventStore containing 20099 events within 9808µs duration; time range within [1724848697953404; 1724848697963212]
# EventStore containing 30125 events within 9809µs duration; time range within [1724848697963412; 1724848697973221]
# EventStore containing 24330 events within 9807µs duration; time range within [1724848697973420; 1724848697983227]
# EventStore containing 24302 events within 9808µs duration; time range within [1724848697983428; 1724848697993236]
# EventStore containing 30458 events within 9806µs duration; time range within [1724848697993437; 1724848698003243]
# EventStore containing 24167 events within 9807µs duration; time range within [1724848698003444; 1724848698013251]
# EventStore containing 17853 events within 9807µs duration; time range within [1724848698013452; 1724848698023259]
# EventStore containing 22031 events within 9807µs duration; time range within [1724848698023460; 1724848698033267]
# EventStore containing 14089 events within 9808µs duration; time range within [1724848698033468; 1724848698043276]
# EventStore containing 18519 events within 9808µs duration; time range within [1724848698043476; 1724848698053284]
# EventStore containing 20125 events within 9807µs duration; time range within [1724848698053484; 1724848698063291]
# EventStore containing 15153 events within 9808µs duration; time range within [1724848698063492; 1724848698073300]
# EventStore containing 32118 events within 9807µs duration; time range within [1724848698073500; 1724848698083307]
# EventStore containing 34802 events within 9610µs duration; time range within [1724848698083508; 1724848698093118]
# EventStore containing 26464 events within 9809µs duration; time range within [1724848698093315; 1724848698103124]
# EventStore containing 30503 events within 9807µs duration; time range within [1724848698103324; 1724848698113131]
# EventStore containing 29602 events within 9809µs duration; time range within [1724848698113331; 1724848698123140]
# EventStore containing 29645 events within 9807µs duration; time range within [1724848698123340; 1724848698133147]
# EventStore containing 32634 events within 9810µs duration; time range within [1724848698133347; 1724848698143157]
# EventStore containing 32145 events within 9807µs duration; time range within [1724848698143356; 1724848698153163]
# EventStore containing 33042 events within 9809µs duration; time range within [1724848698153363; 1724848698163172]
# EventStore containing 29503 events within 9809µs duration; time range within [1724848698163371; 1724848698173180]
# EventStore containing 24855 events within 9808µs duration; time range within [1724848698173379; 1724848698183187]
# EventStore containing 20470 events within 9808µs duration; time range within [1724848698183387; 1724848698193195]
# EventStore containing 15802 events within 9808µs duration; time range within [1724848698193396; 1724848698203204]
# EventStore containing 15301 events within 9808µs duration; time range within [1724848698203404; 1724848698213212]
# EventStore containing 16399 events within 9809µs duration; time range within [1724848698213411; 1724848698223220]
# EventStore containing 23696 events within 9808µs duration; time range within [1724848698223419; 1724848698233227]
# EventStore containing 29265 events within 9805µs duration; time range within [1724848698233430; 1724848698243235]
# EventStore containing 33152 events within 9808µs duration; time range within [1724848698243435; 1724848698253243]
# EventStore containing 31373 events within 9809µs duration; time range within [1724848698253443; 1724848698263252]
# EventStore containing 26583 events within 9807µs duration; time range within [1724848698263452; 1724848698273259]
# EventStore containing 22615 events within 9807µs duration; time range within [1724848698273460; 1724848698283267]
# EventStore containing 21146 events within 9807µs duration; time range within [1724848698283468; 1724848698293275]
# EventStore containing 17639 events within 9807µs duration; time range within [1724848698293476; 1724848698303283]
# EventStore containing 39571 events within 9808µs duration; time range within [1724848698303484; 1724848698313292]
# EventStore containing 46466 events within 9807µs duration; time range within [1724848698313492; 1724848698323299]
# EventStore containing 27419 events within 9607µs duration; time range within [1724848698323500; 1724848698333107]
# EventStore containing 34334 events within 9807µs duration; time range within [1724848698333308; 1724848698343115]
# EventStore containing 35541 events within 9809µs duration; time range within [1724848698343315; 1724848698353124]
# EventStore containing 25770 events within 9808µs duration; time range within [1724848698353323; 1724848698363131]
# EventStore containing 23180 events within 9808µs duration; time range within [1724848698363332; 1724848698373140]
# EventStore containing 23134 events within 9807µs duration; time range within [1724848698373340; 1724848698383147]
# EventStore containing 26774 events within 9807µs duration; time range within [1724848698383348; 1724848698393155]
# EventStore containing 22922 events within 9809µs duration; time range within [1724848698393355; 1724848698403164]
# EventStore containing 26184 events within 9807µs duration; time range within [1724848698403364; 1724848698413171]
# EventStore containing 21595 events within 9808µs duration; time range within [1724848698413371; 1724848698423179]
# EventStore containing 21720 events within 9808µs duration; time range within [1724848698423379; 1724848698433187]
# EventStore containing 28497 events within 9808µs duration; time range within [1724848698433387; 1724848698443195]
# EventStore containing 22175 events within 9808µs duration; time range within [1724848698443395; 1724848698453203]
# EventStore containing 31057 events within 9807µs duration; time range within [1724848698453404; 1724848698463211]
# EventStore containing 25382 events within 9809µs duration; time range within [1724848698463411; 1724848698473220]
# EventStore containing 20321 events within 9807µs duration; time range within [1724848698473420; 1724848698483227]
# EventStore containing 20372 events within 9808µs duration; time range within [1724848698483427; 1724848698493235]
# EventStore containing 12148 events within 9808µs duration; time range within [1724848698493436; 1724848698503244]
# EventStore containing 17603 events within 9809µs duration; time range within [1724848698503444; 1724848698513253]
# EventStore containing 18598 events within 9808µs duration; time range within [1724848698513451; 1724848698523259]
# EventStore containing 16618 events within 9808µs duration; time range within [1724848698523460; 1724848698533268]
# EventStore containing 41004 events within 9808µs duration; time range within [1724848698533468; 1724848698543276]
# EventStore containing 43446 events within 9808µs duration; time range within [1724848698543475; 1724848698553283]
# EventStore containing 26397 events within 9808µs duration; time range within [1724848698553483; 1724848698563291]
# EventStore containing 37642 events within 9808µs duration; time range within [1724848698563491; 1724848698573299]
# EventStore containing 30158 events within 9609µs duration; time range within [1724848698573499; 1724848698583108]
# EventStore containing 21848 events within 9806µs duration; time range within [1724848698583309; 1724848698593115]
# EventStore containing 22477 events within 9808µs duration; time range within [1724848698593315; 1724848698603123]
# EventStore containing 21552 events within 9807µs duration; time range within [1724848698603324; 1724848698613131]
# EventStore containing 17724 events within 9808µs duration; time range within [1724848698613331; 1724848698623139]
# EventStore containing 20123 events within 9808µs duration; time range within [1724848698623339; 1724848698633147]
# EventStore containing 14652 events within 9808µs duration; time range within [1724848698633347; 1724848698643155]
# EventStore containing 23007 events within 9808µs duration; time range within [1724848698643355; 1724848698653163]
# EventStore containing 18592 events within 9807µs duration; time range within [1724848698653364; 1724848698663171]
# EventStore containing 33946 events within 9808µs duration; time range within [1724848698663372; 1724848698673180]
# EventStore containing 29518 events within 9810µs duration; time range within [1724848698673379; 1724848698683189]
# EventStore containing 41338 events within 9807µs duration; time range within [1724848698683388; 1724848698693195]
# EventStore containing 28769 events within 9808µs duration; time range within [1724848698693395; 1724848698703203]
# EventStore containing 28463 events within 9808µs duration; time range within [1724848698703403; 1724848698713211]
# EventStore containing 19944 events within 9808µs duration; time range within [1724848698713411; 1724848698723219]
# EventStore containing 15797 events within 9808µs duration; time range within [1724848698723420; 1724848698733228]
# EventStore containing 23269 events within 9807µs duration; time range within [1724848698733428; 1724848698743235]
# EventStore containing 17788 events within 9807µs duration; time range within [1724848698743436; 1724848698753243]
# EventStore containing 24819 events within 9807µs duration; time range within [1724848698753444; 1724848698763251]
# EventStore containing 35866 events within 9807µs duration; time range within [1724848698763452; 1724848698773259]
# EventStore containing 31441 events within 9808µs duration; time range within [1724848698773460; 1724848698783268]
# EventStore containing 24665 events within 9808µs duration; time range within [1724848698783467; 1724848698793275]
# EventStore containing 40438 events within 9809µs duration; time range within [1724848698793475; 1724848698803284]
# EventStore containing 22513 events within 9808µs duration; time range within [1724848698803483; 1724848698813291]
# EventStore containing 29978 events within 9808µs duration; time range within [1724848698813491; 1724848698823299]
# EventStore containing 24994 events within 9808µs duration; time range within [1724848698823499; 1724848698833307]
# EventStore containing 29802 events within 9608µs duration; time range within [1724848698833507; 1724848698843115]
# EventStore containing 29926 events within 9808µs duration; time range within [1724848698843315; 1724848698853123]
# EventStore containing 31120 events within 9808µs duration; time range within [1724848698853323; 1724848698863131]
# EventStore containing 24839 events within 9808µs duration; time range within [1724848698863331; 1724848698873139]
# EventStore containing 30329 events within 9808µs duration; time range within [1724848698873339; 1724848698883147]
# EventStore containing 21551 events within 9811µs duration; time range within [1724848698883347; 1724848698893158]
# EventStore containing 19490 events within 9811µs duration; time range within [1724848698893355; 1724848698903166]
# EventStore containing 24136 events within 9808µs duration; time range within [1724848698903363; 1724848698913171]
# EventStore containing 31496 events within 9808µs duration; time range within [1724848698913371; 1724848698923179]
# EventStore containing 32966 events within 9808µs duration; time range within [1724848698923379; 1724848698933187]
# EventStore containing 21514 events within 9808µs duration; time range within [1724848698933387; 1724848698943195]
# EventStore containing 30063 events within 9808µs duration; time range within [1724848698943395; 1724848698953203]
# EventStore containing 31677 events within 9809µs duration; time range within [1724848698953404; 1724848698963213]
# EventStore containing 28842 events within 9807µs duration; time range within [1724848698963412; 1724848698973219]
# EventStore containing 23392 events within 9808µs duration; time range within [1724848698973419; 1724848698983227]
# EventStore containing 27352 events within 9808µs duration; time range within [1724848698983427; 1724848698993235]
# EventStore containing 30591 events within 9807µs duration; time range within [1724848698993436; 1724848699003243]
# EventStore containing 27217 events within 9808µs duration; time range within [1724848699003443; 1724848699013251]
# EventStore containing 22787 events within 9808µs duration; time range within [1724848699013451; 1724848699023259]
# EventStore containing 32044 events within 9808µs duration; time range within [1724848699023459; 1724848699033267]
# EventStore containing 17605 events within 9808µs duration; time range within [1724848699033467; 1724848699043275]
# EventStore containing 16966 events within 9808µs duration; time range within [1724848699043475; 1724848699053283]
# EventStore containing 16432 events within 9808µs duration; time range within [1724848699053483; 1724848699063291]
# EventStore containing 23638 events within 9811µs duration; time range within [1724848699063491; 1724848699073302]
# EventStore containing 23476 events within 9808µs duration; time range within [1724848699073499; 1724848699083307]
# EventStore containing 16862 events within 9608µs duration; time range within [1724848699083507; 1724848699093115]
# EventStore containing 24984 events within 9808µs duration; time range within [1724848699093315; 1724848699103123]
# EventStore containing 23729 events within 9808µs duration; time range within [1724848699103323; 1724848699113131]
# EventStore containing 21809 events within 9804µs duration; time range within [1724848699113335; 1724848699123139]
# EventStore containing 13798 events within 9808µs duration; time range within [1724848699123339; 1724848699133147]
# EventStore containing 17186 events within 9808µs duration; time range within [1724848699133347; 1724848699143155]
# EventStore containing 19430 events within 9808µs duration; time range within [1724848699143355; 1724848699153163]
# EventStore containing 18830 events within 9814µs duration; time range within [1724848699153363; 1724848699163177]
# EventStore containing 14135 events within 9807µs duration; time range within [1724848699163372; 1724848699173179]
# EventStore containing 26179 events within 9808µs duration; time range within [1724848699173380; 1724848699183188]
# EventStore containing 24703 events within 9808µs duration; time range within [1724848699183387; 1724848699193195]
# EventStore containing 29086 events within 9809µs duration; time range within [1724848699193395; 1724848699203204]
# EventStore containing 25497 events within 9808µs duration; time range within [1724848699203403; 1724848699213211]
# EventStore containing 41073 events within 9808µs duration; time range within [1724848699213411; 1724848699223219]
# EventStore containing 21068 events within 9808µs duration; time range within [1724848699223419; 1724848699233227]
# EventStore containing 21008 events within 9808µs duration; time range within [1724848699233427; 1724848699243235]
# EventStore containing 16798 events within 9808µs duration; time range within [1724848699243435; 1724848699253243]
# EventStore containing 15033 events within 9807µs duration; time range within [1724848699253444; 1724848699263251]
# EventStore containing 17961 events within 9808µs duration; time range within [1724848699263451; 1724848699273259]
# EventStore containing 14095 events within 9807µs duration; time range within [1724848699273460; 1724848699283267]
# EventStore containing 19579 events within 9808µs duration; time range within [1724848699283467; 1724848699293275]
# EventStore containing 51445 events within 9808µs duration; time range within [1724848699293475; 1724848699303283]
# EventStore containing 41519 events within 9809µs duration; time range within [1724848699303483; 1724848699313292]
# EventStore containing 28520 events within 9808µs duration; time range within [1724848699313491; 1724848699323299]
# EventStore containing 39961 events within 9808µs duration; time range within [1724848699323499; 1724848699333307]
# EventStore containing 25280 events within 9609µs duration; time range within [1724848699333507; 1724848699343116]
# EventStore containing 17192 events within 9805µs duration; time range within [1724848699343318; 1724848699353123]
# EventStore containing 21273 events within 9805µs duration; time range within [1724848699353326; 1724848699363131]
# EventStore containing 28220 events within 9808µs duration; time range within [1724848699363331; 1724848699373139]
# EventStore containing 33888 events within 9808µs duration; time range within [1724848699373339; 1724848699383147]
# EventStore containing 21632 events within 9809µs duration; time range within [1724848699383347; 1724848699393156]
# EventStore containing 36794 events within 9808µs duration; time range within [1724848699393355; 1724848699403163]
# EventStore containing 34915 events within 9809µs duration; time range within [1724848699403363; 1724848699413172]
# EventStore containing 28532 events within 9808µs duration; time range within [1724848699413371; 1724848699423179]
# EventStore containing 22824 events within 9809µs duration; time range within [1724848699423379; 1724848699433188]
# EventStore containing 24064 events within 9808µs duration; time range within [1724848699433387; 1724848699443195]
# EventStore containing 21564 events within 9808µs duration; time range within [1724848699443395; 1724848699453203]
# EventStore containing 20157 events within 9808µs duration; time range within [1724848699453403; 1724848699463211]
# EventStore containing 21826 events within 9808µs duration; time range within [1724848699463411; 1724848699473219]
# EventStore containing 20123 events within 9808µs duration; time range within [1724848699473419; 1724848699483227]
# EventStore containing 19575 events within 9808µs duration; time range within [1724848699483427; 1724848699493235]
# EventStore containing 29649 events within 9808µs duration; time range within [1724848699493435; 1724848699503243]
# EventStore containing 20742 events within 9811µs duration; time range within [1724848699503443; 1724848699513254]
# EventStore containing 29061 events within 9805µs duration; time range within [1724848699513454; 1724848699523259]
# EventStore containing 23635 events within 9808µs duration; time range within [1724848699523459; 1724848699533267]
# EventStore containing 23691 events within 9808µs duration; time range within [1724848699533467; 1724848699543275]
# EventStore containing 17586 events within 9808µs duration; time range within [1724848699543475; 1724848699553283]
# EventStore containing 25815 events within 9808µs duration; time range within [1724848699553483; 1724848699563291]
# EventStore containing 22869 events within 9807µs duration; time range within [1724848699563492; 1724848699573299]
# EventStore containing 24752 events within 9805µs duration; time range within [1724848699573502; 1724848699583307]
# ...
# EventStore containing 1378 events within 9809µs duration; time range within [1724848822053452; 1724848822063261]
# EventStore containing 1196 events within 9810µs duration; time range within [1724848822063456; 1724848822073266]
# EventStore containing 1243 events within 9808µs duration; time range within [1724848822073464; 1724848822083272]
# EventStore containing 1182 events within 9618µs duration; time range within [1724848822083472; 1724848822093090]
# EventStore containing 1268 events within 9981µs duration; time range within [1724848822093312; 1724848822103293]
# EventStore containing 1217 events within 9615µs duration; time range within [1724848822103488; 1724848822113103]
# EventStore containing 1172 events within 9795µs duration; time range within [1724848822113309; 1724848822123104]
# EventStore containing 1249 events within 9778µs duration; time range within [1724848822123332; 1724848822133110]
# EventStore containing 1290 events within 9808µs duration; time range within [1724848822133325; 1724848822143133]
# EventStore containing 1253 events within 9808µs duration; time range within [1724848822143324; 1724848822153132]
# EventStore containing 1213 events within 9818µs duration; time range within [1724848822153326; 1724848822163144]
# EventStore containing 1259 events within 9817µs duration; time range within [1724848822163334; 1724848822173151]
# EventStore containing 1212 events within 9811µs duration; time range within [1724848822173349; 1724848822183160]
# EventStore containing 1240 events within 9811µs duration; time range within [1724848822183356; 1724848822193167]
# EventStore containing 1185 events within 9815µs duration; time range within [1724848822193360; 1724848822203175]
# EventStore containing 1118 events within 9801µs duration; time range within [1724848822203373; 1724848822213174]
# EventStore containing 1182 events within 9793µs duration; time range within [1724848822213390; 1724848822223183]
# EventStore containing 1213 events within 9805µs duration; time range within [1724848822223391; 1724848822233196]
# EventStore containing 1264 events within 9800µs duration; time range within [1724848822233397; 1724848822243197]
# EventStore containing 1171 events within 9807µs duration; time range within [1724848822243405; 1724848822253212]
# EventStore containing 1164 events within 9812µs duration; time range within [1724848822253413; 1724848822263225]
# EventStore containing 1215 events within 9814µs duration; time range within [1724848822263416; 1724848822273230]
# EventStore containing 1212 events within 9814µs duration; time range within [1724848822273424; 1724848822283238]
# EventStore containing 1243 events within 9806µs duration; time range within [1724848822283434; 1724848822293240]
# EventStore containing 1218 events within 9808µs duration; time range within [1724848822293440; 1724848822303248]
# EventStore containing 1242 events within 9801µs duration; time range within [1724848822303455; 1724848822313256]
# EventStore containing 1330 events within 9822µs duration; time range within [1724848822313456; 1724848822323278]
# EventStore containing 1223 events within 9800µs duration; time range within [1724848822323477; 1724848822333277]
# EventStore containing 1228 events within 9817µs duration; time range within [1724848822333479; 1724848822343296]
# EventStore containing 1251 events within 9787µs duration; time range within [1724848822343503; 1724848822353290]
# EventStore containing 1253 events within 9801µs duration; time range within [1724848822353495; 1724848822363296]
# EventStore containing 1152 events within 9613µs duration; time range within [1724848822363497; 1724848822373110]
# EventStore containing 1167 events within 9803µs duration; time range within [1724848822373316; 1724848822383119]
# EventStore containing 1221 events within 9806µs duration; time range within [1724848822383322; 1724848822393128]
# EventStore containing 1202 events within 9839µs duration; time range within [1724848822393321; 1724848822403160]
# EventStore containing 1121 events within 9811µs duration; time range within [1724848822403325; 1724848822413136]
# EventStore containing 1116 events within 9809µs duration; time range within [1724848822413335; 1724848822423144]
# EventStore containing 1185 events within 9793µs duration; time range within [1724848822423359; 1724848822433152]
# EventStore containing 1149 events within 9808µs duration; time range within [1724848822433349; 1724848822443157]
# EventStore containing 1048 events within 9813µs duration; time range within [1724848822443360; 1724848822453173]
# EventStore containing 1102 events within 9814µs duration; time range within [1724848822453377; 1724848822463191]
# EventStore containing 1027 events within 9803µs duration; time range within [1724848822463381; 1724848822473184]
# EventStore containing 1122 events within 9806µs duration; time range within [1724848822473390; 1724848822483196]
# EventStore containing 1149 events within 9789µs duration; time range within [1724848822483408; 1724848822493197]
# EventStore containing 1131 events within 9800µs duration; time range within [1724848822493405; 1724848822503205]
# EventStore containing 1185 events within 9807µs duration; time range within [1724848822503414; 1724848822513221]
# EventStore containing 1127 events within 9759µs duration; time range within [1724848822513465; 1724848822523224]
# EventStore containing 1267 events within 9814µs duration; time range within [1724848822523421; 1724848822533235]
# EventStore containing 1270 events within 9761µs duration; time range within [1724848822533485; 1724848822543246]
# EventStore containing 1288 events within 9811µs duration; time range within [1724848822543437; 1724848822553248]
# EventStore containing 1208 events within 9799µs duration; time range within [1724848822553455; 1724848822563254]
# EventStore containing 1122 events within 9807µs duration; time range within [1724848822563462; 1724848822573269]
# EventStore containing 1107 events within 9811µs duration; time range within [1724848822573465; 1724848822583276]
# EventStore containing 1050 events within 9813µs duration; time range within [1724848822583472; 1724848822593285]
# EventStore containing 1062 events within 9795µs duration; time range within [1724848822593493; 1724848822603288]
# EventStore containing 1042 events within 9813µs duration; time range within [1724848822603493; 1724848822613306]
# EventStore containing 1112 events within 9803µs duration; time range within [1724848822613502; 1724848822623305]
# EventStore containing 1051 events within 9612µs duration; time range within [1724848822623501; 1724848822633113]
# EventStore containing 1092 events within 9811µs duration; time range within [1724848822633309; 1724848822643120]
# EventStore containing 1103 events within 9744µs duration; time range within [1724848822643384; 1724848822653128]
# EventStore containing 1151 events within 9805µs duration; time range within [1724848822653333; 1724848822663138]
# EventStore containing 1103 events within 9809µs duration; time range within [1724848822663336; 1724848822673145]
# EventStore containing 1170 events within 9810µs duration; time range within [1724848822673349; 1724848822683159]
# EventStore containing 1133 events within 9811µs duration; time range within [1724848822683355; 1724848822693166]
# EventStore containing 1176 events within 9803µs duration; time range within [1724848822693365; 1724848822703168]
# EventStore containing 1151 events within 9816µs duration; time range within [1724848822703365; 1724848822713181]
# EventStore containing 1151 events within 9811µs duration; time range within [1724848822713373; 1724848822723184]
# EventStore containing 1195 events within 9799µs duration; time range within [1724848822723390; 1724848822733189]
# EventStore containing 1225 events within 9808µs duration; time range within [1724848822733397; 1724848822743205]
# EventStore containing 1202 events within 9808µs duration; time range within [1724848822743400; 1724848822753208]
# EventStore containing 1154 events within 9805µs duration; time range within [1724848822753411; 1724848822763216]
# EventStore containing 1221 events within 9806µs duration; time range within [1724848822763418; 1724848822773224]
# EventStore containing 1251 events within 9792µs duration; time range within [1724848822773446; 1724848822783238]
# EventStore containing 1213 events within 9859µs duration; time range within [1724848822783432; 1724848822793291]
# EventStore containing 1256 events within 9808µs duration; time range within [1724848822793447; 1724848822803255]
# EventStore containing 1206 events within 9818µs duration; time range within [1724848822803453; 1724848822813271]
# EventStore containing 1356 events within 9816µs duration; time range within [1724848822813463; 1724848822823279]
# EventStore containing 1358 events within 9809µs duration; time range within [1724848822823469; 1724848822833278]
# EventStore containing 1279 events within 9796µs duration; time range within [1724848822833487; 1724848822843283]
# EventStore containing 1322 events within 9613µs duration; time range within [1724848822843480; 1724848822853093]
# EventStore containing 1304 events within 9990µs duration; time range within [1724848822853313; 1724848822863303]
# EventStore containing 1309 events within 9594µs duration; time range within [1724848822863509; 1724848822873103]
# EventStore containing 1328 events within 9792µs duration; time range within [1724848822873323; 1724848822883115]
# EventStore containing 1375 events within 9823µs duration; time range within [1724848822883327; 1724848822893150]
# EventStore containing 1436 events within 9792µs duration; time range within [1724848822893335; 1724848822903127]
# EventStore containing 1384 events within 9805µs duration; time range within [1724848822903336; 1724848822913141]
# EventStore containing 1257 events within 9800µs duration; time range within [1724848822913343; 1724848822923143]
# EventStore containing 1337 events within 9815µs duration; time range within [1724848822923342; 1724848822933157]
# EventStore containing 1399 events within 9797µs duration; time range within [1724848822933362; 1724848822943159]
# EventStore containing 1334 events within 9792µs duration; time range within [1724848822943375; 1724848822953167]
# EventStore containing 1382 events within 9776µs duration; time range within [1724848822953399; 1724848822963175]
# EventStore containing 1339 events within 9807µs duration; time range within [1724848822963382; 1724848822973189]
# EventStore containing 1336 events within 9793µs duration; time range within [1724848822973396; 1724848822983189]
# EventStore containing 1292 events within 9801µs duration; time range within [1724848822983397; 1724848822993198]
# EventStore containing 1273 events within 9794µs duration; time range within [1724848822993413; 1724848823003207]
# EventStore containing 1250 events within 9803µs duration; time range within [1724848823003413; 1724848823013216]
# EventStore containing 1315 events within 9806µs duration; time range within [1724848823013419; 1724848823023225]
# EventStore containing 1238 events within 9816µs duration; time range within [1724848823023425; 1724848823033241]
# EventStore containing 1292 events within 9816µs duration; time range within [1724848823033430; 1724848823043246]
# EventStore containing 1222 events within 9815µs duration; time range within [1724848823043440; 1724848823053255]
# EventStore containing 1300 events within 9804µs duration; time range within [1724848823053458; 1724848823063262]
# EventStore containing 1355 events within 9811µs duration; time range within [1724848823063456; 1724848823073267]
# EventStore containing 1412 events within 9811µs duration; time range within [1724848823073464; 1724848823083275]
# EventStore containing 1344 events within 9814µs duration; time range within [1724848823083474; 1724848823093288]
# EventStore containing 1267 events within 9813µs duration; time range within [1724848823093480; 1724848823103293]
# EventStore containing 1350 events within 9607µs duration; time range within [1724848823103495; 1724848823113102]
# EventStore containing 1316 events within 9795µs duration; time range within [1724848823113316; 1724848823123111]
# EventStore containing 1315 events within 9800µs duration; time range within [1724848823123311; 1724848823133111]
# EventStore containing 1288 events within 9808µs duration; time range within [1724848823133315; 1724848823143123]
# EventStore containing 1272 events within 9783µs duration; time range within [1724848823143342; 1724848823153125]
# EventStore containing 1213 events within 9810µs duration; time range within [1724848823153324; 1724848823163134]
# EventStore containing 1186 events within 9808µs duration; time range within [1724848823163335; 1724848823173143]
# EventStore containing 1241 events within 9810µs duration; time range within [1724848823173348; 1724848823183158]
# EventStore containing 1210 events within 9810µs duration; time range within [1724848823183351; 1724848823193161]
# EventStore containing 1181 events within 9807µs duration; time range within [1724848823193359; 1724848823203166]
# EventStore containing 1124 events within 9802µs duration; time range within [1724848823203373; 1724848823213175]
# EventStore containing 1211 events within 9844µs duration; time range within [1724848823213383; 1724848823223227]
# EventStore containing 1272 events within 9811µs duration; time range within [1724848823223387; 1724848823233198]
# EventStore containing 1327 events within 9816µs duration; time range within [1724848823233389; 1724848823243205]
# EventStore containing 1268 events within 9809µs duration; time range within [1724848823243406; 1724848823253215]
# EventStore containing 1250 events within 9800µs duration; time range within [1724848823253415; 1724848823263215]
# EventStore containing 1223 events within 9776µs duration; time range within [1724848823263447; 1724848823273223]
# EventStore containing 1252 events within 9809µs duration; time range within [1724848823273429; 1724848823283238]
# EventStore containing 1209 events within 9812µs duration; time range within [1724848823283431; 1724848823293243]
# EventStore containing 1305 events within 9811µs duration; time range within [1724848823293436; 1724848823303247]
# EventStore containing 1212 events within 9811µs duration; time range within [1724848823303446; 1724848823313257]
# EventStore containing 1210 events within 9804µs duration; time range within [1724848823313487; 1724848823323291]
# EventStore containing 1098 events within 9799µs duration; time range within [1724848823323471; 1724848823333270]
# EventStore containing 1207 events within 9810µs duration; time range within [1724848823333476; 1724848823343286]
# EventStore containing 1091 events within 9807µs duration; time range within [1724848823343486; 1724848823353293]
# EventStore containing 1171 events within 9807µs duration; time range within [1724848823353487; 1724848823363294]
# EventStore containing 1244 events within 9778µs duration; time range within [1724848823363525; 1724848823373303]
# EventStore containing 1170 events within 9617µs duration; time range within [1724848823373502; 1724848823383119]
# EventStore containing 1165 events within 9800µs duration; time range within [1724848823383319; 1724848823393119]
# EventStore containing 1218 events within 9781µs duration; time range within [1724848823393346; 1724848823403127]
# EventStore containing 1222 events within 9805µs duration; time range within [1724848823403334; 1724848823413139]
# EventStore containing 1168 events within 9793µs duration; time range within [1724848823413350; 1724848823423143]
# EventStore containing 1201 events within 9802µs duration; time range within [1724848823423349; 1724848823433151]
# EventStore containing 1216 events within 9806µs duration; time range within [1724848823433358; 1724848823443164]
# EventStore containing 1235 events within 9813µs duration; time range within [1724848823443359; 1724848823453172]
# EventStore containing 1200 events within 9802µs duration; time range within [1724848823453373; 1724848823463175]

# %% [markdown]
# **Read IMU data**

# %%
import dv_processing as dv

# Open a file
reader = dv.io.MonoCameraRecording("../data/robotics.aedat4")

# Run the loop while stream contains data
while reader.isRunning():
    # Read a batch of IMU data from the camera
    imu_batch = reader.getNextImuBatch()
    if imu_batch is not None and len(imu_batch) > 0:
        # Print the info of the imu data
        print(f"Received {len(imu_batch)} IMU measurements")
# Out:
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 7 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# Received 8 IMU measurements
# ...
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 8 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 8 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 6 IMU measurements
# Received 11 IMU measurements
# Received 6 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 7 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 6 IMU measurements
# Received 10 IMU measurements
# Received 7 IMU measurements
# Received 9 IMU measurements

# %% [markdown]
# **Read triggers data**

# %%
import dv_processing as dv

# Open a file
reader = dv.io.MonoCameraRecording("../data/robotics.aedat4")

# Run the loop while camera is still connected
while reader.isRunning():
    # Read a a batch of triggers from the camera
    triggers = reader.getNextTriggerBatch()

    # Check whether batch is valid and contains data
    if triggers is not None and len(triggers) > 0:
        # Print the trigger batch information
        print(f"Received {len(triggers)} triggers")

# %%
## Try to use time surface for visualization
import dv_processing as dv
import cv2 as cv
from datetime import timedelta

# Open any camera
reader = dv.io.MonoCameraRecording("../data/robotics.aedat4")
surface = dv.TimeSurface(reader.getEventResolution())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass the events to update the time surface
    surface.accept(events)

    # Generate a preview frame
    frame = surface.generateFrame()

    # Show the accumulated image
    cv.imshow("Preview", frame.image)
    cv.waitKey(2)


# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while reader.isRunning():
    # Receive events
    events = reader.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)
# Out:
# objc[90109]: Class CaptureDelegate is implemented in both /Users/gg/Library/Python/3.9/lib/python/site-packages/dv_processing.dylibs/libopencv_videoio.4.8.0.dylib (0x10dd90880) and /Users/gg/Library/Python/3.9/lib/python/site-packages/cv2/cv2.abi3.so (0x35c66e5d8). One of the two will be used. Which one is undefined.
# objc[90109]: Class CVWindow is implemented in both /Users/gg/Library/Python/3.9/lib/python/site-packages/dv_processing.dylibs/libopencv_highgui.4.8.0.dylib (0x10d410b38) and /Users/gg/Library/Python/3.9/lib/python/site-packages/cv2/cv2.abi3.so (0x35c66e628). One of the two will be used. Which one is undefined.
# objc[90109]: Class CVView is implemented in both /Users/gg/Library/Python/3.9/lib/python/site-packages/dv_processing.dylibs/libopencv_highgui.4.8.0.dylib (0x10d410b60) and /Users/gg/Library/Python/3.9/lib/python/site-packages/cv2/cv2.abi3.so (0x35c66e650). One of the two will be used. Which one is undefined.
# objc[90109]: Class CVSlider is implemented in both /Users/gg/Library/Python/3.9/lib/python/site-packages/dv_processing.dylibs/libopencv_highgui.4.8.0.dylib (0x10d410b88) and /Users/gg/Library/Python/3.9/lib/python/site-packages/cv2/cv2.abi3.so (0x35c66e678). One of the two will be used. Which one is undefined.
# 2024-08-30 15:19:14.263 Python[90109:1632632] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 58
#      55 # Check if anything was received
#      56 if events is not None:
#      57     # If so, pass the events into the slicer to handle them
# ---> 58     slicer.accept(events)
#
# Cell In[7], line 44, in slicing_callback(events)
#      42 # Show the accumulated image
#      43 cv.imshow("Preview", frame.image)
# ---> 44 cv.waitKey(2)
#
# KeyboardInterrupt:

# %%
# speed invariant time surface
## Try to use time surface for visualization
import dv_processing as dv
import cv2 as cv
from datetime import timedelta

# Open any camera
reader = dv.io.MonoCameraRecording("../data/robotics.aedat4")
surface = dv.SpeedInvariantTimeSurface(reader.getEventResolution())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass the events to update the time surface
    surface.accept(events)

    # Generate a preview frame
    frame = surface.generateFrame()

    # Show the accumulated image
    cv.imshow("Preview", frame.image)
    cv.waitKey(2)


# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while reader.isRunning():
    # Receive events
    events = reader.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)
# Out:
# objc[90669]: Class CaptureDelegate is implemented in both /Users/gg/Library/Python/3.9/lib/python/site-packages/dv_processing.dylibs/libopencv_videoio.4.8.0.dylib (0x112568880) and /Users/gg/Library/Python/3.9/lib/python/site-packages/cv2/cv2.abi3.so (0x3455d65d8). One of the two will be used. Which one is undefined.
# objc[90669]: Class CVWindow is implemented in both /Users/gg/Library/Python/3.9/lib/python/site-packages/dv_processing.dylibs/libopencv_highgui.4.8.0.dylib (0x1119b8b38) and /Users/gg/Library/Python/3.9/lib/python/site-packages/cv2/cv2.abi3.so (0x3455d6628). One of the two will be used. Which one is undefined.
# objc[90669]: Class CVView is implemented in both /Users/gg/Library/Python/3.9/lib/python/site-packages/dv_processing.dylibs/libopencv_highgui.4.8.0.dylib (0x1119b8b60) and /Users/gg/Library/Python/3.9/lib/python/site-packages/cv2/cv2.abi3.so (0x3455d6650). One of the two will be used. Which one is undefined.
# objc[90669]: Class CVSlider is implemented in both /Users/gg/Library/Python/3.9/lib/python/site-packages/dv_processing.dylibs/libopencv_highgui.4.8.0.dylib (0x1119b8b88) and /Users/gg/Library/Python/3.9/lib/python/site-packages/cv2/cv2.abi3.so (0x3455d6678). One of the two will be used. Which one is undefined.
# 2024-08-30 15:28:57.433 Python[90669:1659773] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 42
#      39 # Check if anything was received
#      40 if events is not None:
#      41     # If so, pass the events into the slicer to handle them
# ---> 42     slicer.accept(events)
#
# Cell In[1], line 28, in slicing_callback(events)
#      26 # Show the accumulated image
#      27 cv.imshow("Preview", frame.image)
# ---> 28 cv.waitKey(2)
#
# KeyboardInterrupt:

# %%
import dv_processing as dv
import cv2 as cv
from datetime import timedelta

# Open any camera
reader = dv.io.MonoCameraRecording("../data/robotics.aedat4")
surface = dv.TimeSurface(reader.getEventResolution())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()

# Initialize VideoWriter
frame_width, frame_height = reader.getEventResolution()
fourcc = cv.VideoWriter_fourcc(*'MJPG')  # Try different codecs if needed
out = cv.VideoWriter('output.avi', fourcc, 30.0, (frame_width, frame_height), isColor=True)

# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass the events to update the time surface
    surface.accept(events)

    # Generate a preview frame
    frame = surface.generateFrame()

    # Convert the frame to BGR if it is not already
    bgr_frame = cv.cvtColor(frame.image, cv.COLOR_GRAY2BGR)

    # Show the accumulated image
    cv.imshow("Preview", bgr_frame)

    # Write the frame to the video file
    out.write(bgr_frame)

    # Wait for a short period to allow for window events
    if cv.waitKey(33) & 0xFF == ord('q'):  # Press 'q' to exit
        return

# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while reader.isRunning():
    # Receive events
    events = reader.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)

# Release the VideoWriter object and destroy all windows
out.release()
cv.destroyAllWindows()

# %%
# accumulating events

import dv_processing as dv
import cv2 as cv
from datetime import timedelta

# Open any camera
reader = dv.io.MonoCameraRecording("../data/robotics.aedat4")

# Initialize an accumulator with some resolution
accumulator = dv.Accumulator(reader.getEventResolution())

# Apply configuration, these values can be modified to taste
accumulator.setMinPotential(0.0)
accumulator.setMaxPotential(1.0)
accumulator.setNeutralPotential(0.5)
accumulator.setEventContribution(0.15)
accumulator.setDecayFunction(dv.Accumulator.Decay.EXPONENTIAL)
accumulator.setDecayParam(1e+6)
accumulator.setIgnorePolarity(False)
accumulator.setSynchronousDecay(False)

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()

# Initialize VideoWriter
frame_width, frame_height = reader.getEventResolution()
fourcc = cv.VideoWriter_fourcc(*'MJPG')  # Try different codecs if needed
out = cv.VideoWriter('output.avi', fourcc, 30.0, (frame_width, frame_height), isColor=True)

# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass the events to update the time surface
    accumulator.accept(events)

    # Generate a preview frame
    frame = accumulator.generateFrame()

    # Convert the frame to BGR if it is not already
    bgr_frame = cv.cvtColor(frame.image, cv.COLOR_GRAY2BGR)

    # Show the accumulated image
    cv.imshow("Preview", bgr_frame)

    # Write the frame to the video file
    out.write(bgr_frame)

    # Wait for a short period to allow for window events
    if cv.waitKey(33) & 0xFF == ord('q'):  # Press 'q' to exit
        return

# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while reader.isRunning():
    # Receive events
    events = reader.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)

# Release the VideoWriter object and destroy all windows
out.release()
cv.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Edge acummulating events
# Events occur without considering polarity

import dv_processing as dv
import cv2 as cv
from datetime import timedelta

# Open any camera
reader = dv.io.MonoCameraRecording("../data/robotics.aedat4")

# Initialize an accumulator with some resolution
visualizer = dv.visualization.EventVisualizer(reader.getEventResolution())

# Apply color scheme configuration, these values can be modified to taste
visualizer.setBackgroundColor(dv.visualization.colors.white())
visualizer.setPositiveColor(dv.visualization.colors.iniBlue())
visualizer.setNegativeColor(dv.visualization.colors.iniBlue())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()

# Initialize VideoWriter
frame_width, frame_height = reader.getEventResolution()
fourcc = cv.VideoWriter_fourcc(*'MJPG')  # Try different codecs if needed
out = cv.VideoWriter('output.avi', fourcc, 30.0, (frame_width, frame_height), isColor=True)

# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):

    # Generate a preview frame
    frame = visualizer.generateImage(events)

    # Show the accumulated image
    cv.imshow("Preview", frame)

    # Write the frame to the video file
    out.write(frame)

    # Wait for a short period to allow for window events
    if cv.waitKey(33) & 0xFF == ord('q'):  # Press 'q' to exit
        return

# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while reader.isRunning():
    # Receive events
    events = reader.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)

# Release the VideoWriter object and destroy all windows
out.release()
cv.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# for hand
## Try to use time surface for visualization
import dv_processing as dv
import cv2 as cv
from datetime import timedelta

# Open any camera
reader = dv.io.MonoCameraRecording("./hand.aedat4")
surface = dv.TimeSurface(reader.getEventResolution())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass the events to update the time surface
    surface.accept(events)

    # Generate a preview frame
    frame = surface.generateFrame()

    # Show the accumulated image
    cv.imshow("Preview", frame.image)
    cv.waitKey(2)


# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while reader.isRunning():
    # Receive events
    events = reader.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 42
#      39 # Check if anything was received
#      40 if events is not None:
#      41     # If so, pass the events into the slicer to handle them
# ---> 42     slicer.accept(events)
#
# Cell In[2], line 28, in slicing_callback(events)
#      26 # Show the accumulated image
#      27 cv.imshow("Preview", frame.image)
# ---> 28 cv.waitKey(2)
#
# KeyboardInterrupt:

# %%
# hand speed invariant time surface
# speed invariant time surface
## Try to use time surface for visualization
import dv_processing as dv
import cv2 as cv
from datetime import timedelta

# Open any camera
reader = dv.io.MonoCameraRecording("./hand.aedat4")
surface = dv.SpeedInvariantTimeSurface(reader.getEventResolution())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass the events to update the time surface
    surface.accept(events)

    # Generate a preview frame
    frame = surface.generateFrame()

    # Show the accumulated image
    cv.imshow("Preview", frame.image)
    cv.waitKey(2)


# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while reader.isRunning():
    # Receive events
    events = reader.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)

# %%
import dv_processing as dv
import cv2 as cv
from datetime import timedelta
import os

# Create the output directory if it doesn't exist
output_dir = "./hand_edge"
os.makedirs(output_dir, exist_ok=True)

# Open the camera recording
reader = dv.io.MonoCameraRecording("./hand.aedat4")

# Initialize an accumulator with the event resolution
visualizer = dv.visualization.EventVisualizer(reader.getEventResolution())

# Apply color scheme configuration
visualizer.setBackgroundColor(dv.visualization.colors.white())
visualizer.setPositiveColor(dv.visualization.colors.iniBlue())
visualizer.setNegativeColor(dv.visualization.colors.iniBlue())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()

# Initialize VideoWriter
frame_width, frame_height = reader.getEventResolution()
fourcc = cv.VideoWriter_fourcc(*'MJPG')
out = cv.VideoWriter('hand_edge.avi', fourcc, 30.0, (frame_width, frame_height), isColor=True)

# Initialize frame counter
frame_count = 0

# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    global frame_count
    
    # Generate a preview frame
    frame = visualizer.generateImage(events)

    # Show the accumulated image
    cv.imshow("Preview", frame)

    # Write the frame to the video file
    out.write(frame)

    # Save the frame as an image in the output directory
    frame_filename = os.path.join(output_dir, f"frame_{frame_count:04d}.png")
    cv.imwrite(frame_filename, frame)
    frame_count += 1

    # Wait for a short period to allow for window events
    if cv.waitKey(33) & 0xFF == ord('q'):  # Press 'q' to exit
        return

# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is running
while reader.isRunning():
    events = reader.getNextEventBatch()
    if events is not None:
        slicer.accept(events)

# Release the VideoWriter object and destroy all windows
out.release()
cv.destroyAllWindows()
